# %%
import pandas as pd

# %%
train = pd.read_csv('./Dacon/funda_train.csv')

# %%
train.head(6)
# Out:
#    store_id  card_id card_company transacted_date transacted_time  \
# 0         0        0            b      2016-06-01           13:13
# 1         0        1            h      2016-06-01           18:12
# 2         0        2            c      2016-06-01           18:52
# 3         0        3            a      2016-06-01           20:22
# 4         0        4            c      2016-06-02           11:06
# 5         0        5            c      2016-06-02           13:09
#
#    installment_term region type_of_business       amount
# 0                 0    NaN           기타 미용업  1857.142857
# 1                 0    NaN           기타 미용업   857.142857
# 2                 0    NaN           기타 미용업  2000.000000
# 3                 0    NaN           기타 미용업  7857.142857
# 4                 0    NaN           기타 미용업  2000.000000
# 5                 0    NaN           기타 미용업  2000.000000

# %% [markdown]
# ## 처음 추정치

# %%
set_amount = train[(train['transacted_date']>='2018-03-01') & (train['transacted_date'] <= '2018-05-31')]

# %%
main_expectations = set_amount.groupby('store_id')['amount'].sum()

# %%
main_expectations
# Out:
# store_id
# 0       2.171000e+06
# 1       2.977143e+05
# 2       9.461429e+05
# 4       2.475643e+06
# 5       1.111857e+06
#             ...
# 2132    2.518143e+06
# 2133    1.418629e+06
# 2134    5.340714e+05
# 2135    1.491000e+06
# 2136    6.743929e+06
# Name: amount, Length: 1955, dtype: float64

# %% [markdown]
# ## 새로운 방법
# ### 1. (2019년 1월~2월까지의 매출의 합/ 59(일))*92
# * 최근 두달동안의 일 평균 매출을 구해서 19.03.01 ~ 19.05.31 사이의 날짜만큼 매출로 추정해본다.
#
# ### 2. 92일 동안의 요일별 갯수를 구해서 각 스토어의 요일별 매출을 날짜 수로 나눠서 구해본다.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ### + 모두 다 한 다음에 전에 구했던 추정치 결과값에 붙여준다.(union 사용)

# %% [markdown]
# # 잃어버린 데이터를 찾아서

# %%
set_amount = train[(train['transacted_date']>='2018-03-01') & (train['transacted_date'] <= '2018-05-31')]

# %%
missing_datas = train[~(train['store_id'].isin(set_amount['store_id']))]

# %%
missing_datas
# Out:
#          store_id  card_id card_company transacted_date transacted_time  \
# 779947        271   522127            a      2016-06-01           13:05
# 779948        271   522128            f      2016-06-01           13:06
# 779949        271   522129            g      2016-06-01           13:08
# 779950        271   522130            d      2016-06-01           13:15
# 779951        271   522131            b      2016-06-01           14:38
# ...           ...      ...          ...             ...             ...
# 6492850      2119  4629273            c      2018-02-12           13:34
# 6492851      2119  4629260            c      2018-02-20           12:16
# 6492852      2119  4629276            d      2018-02-20           15:33
# 6492853      2119  4629261            a      2018-02-26           13:22
# 6492854      2119  4629269            d      2018-02-27           12:10
#
#          installment_term region type_of_business         amount
# 779947                  0  인천 남구              NaN    2285.714286
# 779948                  0  인천 남구              NaN    8414.285714
# 779949                  0  인천 남구              NaN    1350.000000
# 779950                  0  인천 남구              NaN    1428.571429
# 779951                  0  인천 남구              NaN    6285.714286
# ...                   ...    ...              ...            ...
# 6492850                 0    NaN              NaN   60000.000000
# 6492851                 0    NaN              NaN  296428.571429
# 6492852                 0    NaN              NaN  110000.000000
# 6492853                 0    NaN              NaN  122857.142857
# 6492854                 0    NaN              NaN   94000.000000
#
# [22721 rows x 9 columns]

# %%
missing_id = missing_datas['store_id'].unique()

# %% [markdown]
# ## 1. (2019년 1월~2월까지의 매출의 합/ 59(일))*92

# %%
train
# Out:
#          store_id  card_id card_company transacted_date transacted_time  \
# 0               0        0            b      2016-06-01           13:13
# 1               0        1            h      2016-06-01           18:12
# 2               0        2            c      2016-06-01           18:52
# 3               0        3            a      2016-06-01           20:22
# 4               0        4            c      2016-06-02           11:06
# ...           ...      ...          ...             ...             ...
# 6556608      2136  4663855            d      2019-02-28           23:20
# 6556609      2136  4663855            d      2019-02-28           23:24
# 6556610      2136  4663489            a      2019-02-28           23:24
# 6556611      2136  4663856            d      2019-02-28           23:27
# 6556612      2136  4658616            c      2019-02-28           23:54
#
#          installment_term  region type_of_business       amount
# 0                       0     NaN           기타 미용업  1857.142857
# 1                       0     NaN           기타 미용업   857.142857
# 2                       0     NaN           기타 미용업  2000.000000
# 3                       0     NaN           기타 미용업  7857.142857
# 4                       0     NaN           기타 미용업  2000.000000
# ...                   ...     ...              ...          ...
# 6556608                 0  제주 제주시           기타 주점업 -4500.000000
# 6556609                 0  제주 제주시           기타 주점업  4142.857143
# 6556610                 0  제주 제주시           기타 주점업  4500.000000
# 6556611                 0  제주 제주시           기타 주점업   571.428571
# 6556612                 0  제주 제주시           기타 주점업  5857.142857
#
# [6556613 rows x 9 columns]

# %%
missing_stores = missing_datas[(missing_datas['transacted_date'] >= '2019-01-01')&(missing_datas['transacted_date'] <= '2019-02-29')]

# %%
missing_stores
# Out:
#          store_id  card_id card_company transacted_date transacted_time  \
# 785990        271   524967            b      2019-01-03           12:52
# 785991        271   524968            f      2019-01-04           21:35
# 785992        271   524969            b      2019-01-04           21:36
# 785993        271   524970            a      2019-01-04           21:37
# 785994        271   524971            a      2019-01-04           21:39
# ...           ...      ...          ...             ...             ...
# 6398249      2094  4570475            b      2019-02-24           20:08
# 6398250      2094  3021200            b      2019-02-25           23:36
# 6398251      2094  4570476            b      2019-02-26           20:48
# 6398252      2094  4570477            a      2019-02-27           21:24
# 6398253      2094  4570478            c      2019-02-27           23:58
#
#          installment_term  region type_of_business        amount
# 785990                  0   인천 남구              NaN  8.142857e+03
# 785991                  5   인천 남구              NaN  7.142857e+05
# 785992                  5   인천 남구              NaN  5.714286e+05
# 785993                  5   인천 남구              NaN  6.428571e+05
# 785994                  5   인천 남구              NaN  1.071429e+06
# ...                   ...     ...              ...           ...
# 6398249                 0  경북 칠곡군              NaN  5.000000e+03
# 6398250                 0  경북 칠곡군              NaN  4.857143e+03
# 6398251                 0  경북 칠곡군              NaN  3.571429e+03
# 6398252                 0  경북 칠곡군              NaN  3.571429e+03
# 6398253                 0  경북 칠곡군              NaN  2.857143e+03
#
# [1371 rows x 9 columns]

# %%
missing_stores.groupby('store_id')['amount'].sum()
# Out:
# store_id
# 271     1.024661e+07
# 279     2.295000e+05
# 515     6.595714e+04
# 588     3.897143e+04
# 706     4.069143e+05
# 795     0.000000e+00
# 1379    1.016071e+06
# 1435    7.361429e+05
# 2081    8.412086e+05
# 2094    2.816429e+05
# Name: amount, dtype: float64

# %%
missing_expectation = missing_stores.groupby('store_id')['amount'].sum()/59*92

# %%
missing_expectation
# Out:
# store_id
# 271     1.597776e+07
# 279     3.578644e+05
# 515     1.028484e+05
# 588     6.076901e+04
# 706     6.345104e+05
# 795     0.000000e+00
# 1379    1.584383e+06
# 1435    1.147884e+06
# 2081    1.311715e+06
# 2094    4.391719e+05
# Name: amount, dtype: float64

# %% [markdown]
# ## 합쳐보자

# %%
main_expectations
# Out:
# store_id
# 0       2.171000e+06
# 1       2.977143e+05
# 2       9.461429e+05
# 4       2.475643e+06
# 5       1.111857e+06
#             ...
# 2132    2.518143e+06
# 2133    1.418629e+06
# 2134    5.340714e+05
# 2135    1.491000e+06
# 2136    6.743929e+06
# Name: amount, Length: 1955, dtype: float64

# %%
missing_expectation
# Out:
# store_id
# 271     1.597776e+07
# 279     3.578644e+05
# 515     1.028484e+05
# 588     6.076901e+04
# 706     6.345104e+05
# 795     0.000000e+00
# 1379    1.584383e+06
# 1435    1.147884e+06
# 2081    1.311715e+06
# 2094    4.391719e+05
# Name: amount, dtype: float64

# %%
result = pd.concat([main_expectastions, missing_expectation])

# %%
result.to_csv('./Dacon/second_test.csv')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ### missing 된 것들이 있는지 알아보는 법

# %%
len(missing_id)
# Out:
# 12

# %%
missing_stores['store_id'].isin(list(missing_id))
# Out:
# 785990     True
# 785991     True
# 785992     True
# 785993     True
# 785994     True
#            ...
# 6398249    True
# 6398250    True
# 6398251    True
# 6398252    True
# 6398253    True
# Name: store_id, Length: 1371, dtype: bool

# %% [markdown]
# ##  92일 동안의 요일별 갯수를 구해서 각 스토어의 요일별 매출을 날짜 수로 나눠서 구해본다.

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-100-ad08c08a13b9> in <module>
# ----> 1 pd.DataFram
#
# AttributeError: module 'pandas' has no attribute 'DataFram'
